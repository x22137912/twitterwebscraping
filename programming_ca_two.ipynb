# %% [markdown]
# Group Memebers
#
# *   Chirag Gupta - 10623123
# *   Chukwuebuka Uwaoma - 10621864
# *   Dipanshu

# %%
# Import necesarry libraries
import tweepy
import os

# %%
# Load dotenv and read secret keys and tokens
load_dotenv()
api_key = os.getenv('api_key')
api_secret_key = os.getenv('api_secret_key')
access_token = os.getenv('access_token')
access_token_secret = os.getenv('access_token_secret')

# %%
# Connect to twitter using tweepy API and stored tokens
auth = tweepy.OAuthHandler(api_key,api_secret_key)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
# Pulls tweets based on search query and geocode location
tweetlist = []
geocode="53.3498053,-6.2603097,25km"
tweets = tweepy.Cursor(api.search_tweets, q='cars', geocode=geocode, lang='en', tweet_mode="extended", count=100).items(200)

# print each tweet's text
for tweet in tweets:
    if hasattr(tweet, "retweeted_status"):
        tweet = tweet.retweeted_status
    if hasattr(tweet, "full_text"):
        tweetlist.append(tweet.full_text)
    else:
        tweetlist.append(tweet.text)
# Out:
# 200

# %%
for t in tweetlist:
    print(t[:9])
# Out:
# You were
# The poor
# Bid &amp;
# Biden unv
# Today, my
# I started
# All 3 car
# Today, my
# EPA admin
# Today, af
# Team #BMC
# Today, my
# Today, my
# Biden unv
# @Ravisuta
# Today, my
# https://t
# The 🇺🇦 De
# pretty go
# Today, af
# Today, my
# Today, my
# Joe Biden
# Today, my
# Today, my
# @ID_AA_Ca
# Women dri
# Flatbed T
# @News3LV
# Biden abu
# Today, my
# niggas ou
# Today, my
# 🤳 TOYOTA
# Sui Testn
# Not even
# Today, my
# This is i
# This is v
# Pineapple
# The real
# niggas ou
# Women dri
# @dave_wha
# First mov
# @aitchrob
# Today the
# "In the p
# Today, my
# Today, my
# Rich elit
# Toyota ow
# @CarolCon
# BREAKING:
# Today, my
# or you co
# Today, my
# Today, af
# @Bravado_
# If Muslim
# Pineapple
# Today, my
# #NowPlayi
# The 🇺🇦 De
# @MiExecSe
# niggas ou
# @krassens
# Today, af
# Sui Testn
# This is v
# Breaking:
# Spent an
# All cars
# @RealJame
# Rodri has
# @420_hack
# Cheap car
# I need oi
# Today, my
# Alice has
# Today, my
# @Mrs_KTJ
# ⚠️ Earth
# Today, my
# @mouldY56
# Today, my
# Today, my
# Today, my
# Today, my
# @classwor
# Joe Biden
# 1.6BN shi
# Thanks @B
# @joncoope
# Today, my
# Today, af
# Today, my
# The WH ne
# Today, my
# @WhatAbou
# Today, my
# @GAgirlfr
# @alc2022
# Cool look
# Tbh, the
# Cars are
# Today, my
# 1. Remind
# Today, my
# ab to ste
# New look
# The Envir
# literally
# No one wi
# Biden is
# Today, af
# Rainy Cyb
# Apr 11, 1
# @lukespra
# @BobBlack
# Biden's p
# Did you k
# 1. Remind
# part of m
# Astonishi
# Today, my
# DC regula
# Today, af
# @TataMoto
# @KalergiW
# New look
# Hey, it's
# Today, my
# Biden tor
# Women dri
# Today, my
# Today, my
# Today, my
# Today, my
# The next
# New look
# Thursday
# Today, my
# “We’re qu
# Today, my
# @POTUS Ba
# Today, we
# @CNN The
# @Jayecane
# 📺 LIVE NO
# @JuhiMeh9
# @EzerRatc
# It’s a sh
# Cars for
# Today, my
# Today, my
# @nytimes
# Not only
# @dc_homer
# IQ of a t
# Today, my
# Today, my
# Today, my
# Today, my
# @antoniog
# https://t
# I miss wh
# I wish we
# Today, af
# Today, my
# Today, my
# Today, my
# It’s a sh
# @chxrliew
# "In the p
# I’m someb
# @creation
# @RealJame
# Ana Kaspa
# Not only
# Today, my
# @mtkblb @
# #StormNoa
# @Scribula
# Today, my
# Uber driv
# Today, my
# Today, my
# @davidhog
# Today, my
# Today, my
# Good remi
# Biden's p
# Today, my
# Today, we
# Today, my
# Today, my
# @larryeld
# Today, my
# 📣  Xranil
